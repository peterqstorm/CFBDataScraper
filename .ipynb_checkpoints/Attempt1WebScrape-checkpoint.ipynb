# %%
from urllib.request import Request,urlopen
from bs4 import BeautifulSoup, Comment
import re, os

# %%
#accessurl = 'https://www.sports-reference.com/cfb/schools/oklahoma-state/2016/gamelog/'
#req = Request(accessurl)
#link = urlopen(req)
file_input = 'Sample_okstate_html'
if not os.path.isfile(file_input + '.txt'):
    print('error file not found')
with open(file_input + '.txt') as f:
    soup = BeautifulSoup(input_file, "lxml")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-907cb57155be> in <module>()
#       3 #link = urlopen(req)
#       4 file_input = 'Sample_okstate_html'
# ----> 5 if not os.path.isfile(us_counties+'.shp'):
#       6     print('error file not found')
#       7 with open(file_input + '.txt') as f:
#
# NameError: name 'us_counties' is not defined

# %%
tables = soup.find_all(['th', 'tr'])
print(len(tables))
print(tables)
my_table = tables[0]
rows = my_table.findChildren(['tr'])
for row in rows:
    cells = row.findChildren('td')
    for cell in cells:
        value = cell.string
        print(value)
# Out:
# 63
# [<tr class="over_header">
# <th aria-label="" class=" over_header center" colspan="5" data-stat=""></th>
# <th aria-label="" class=" over_header center" colspan="5" data-stat="header_passing">Passing</th>
# <th aria-label="" class=" over_header center" colspan="4" data-stat="header_rushing">Rushing</th>
# <th aria-label="" class=" over_header center" colspan="3" data-stat="header_tot_off">Total Offense</th>
# <th aria-label="" class=" over_header center" colspan="4" data-stat="header_first_downs">First Downs</th>
# <th aria-label="" class=" over_header center" colspan="2" data-stat="header_penalties">Penalties</th>
# <th aria-label="" class=" over_header center" colspan="3" data-stat="header_turnovers">Turnovers</th>
# </tr>, <th aria-label="" class=" over_header center" colspan="5" data-stat=""></th>, <th aria-label="" class=" over_header center" colspan="5" data-stat="header_passing">Passing</th>, <th aria-label="" class=" over_header center" colspan="4" data-stat="header_rushing">Rushing</th>, <th aria-label="" class=" over_header center" colspan="3" data-stat="header_tot_off">Total Offense</th>, <th aria-label="" class=" over_header center" colspan="4" data-stat="header_first_downs">First Downs</th>, <th aria-label="" class=" over_header center" colspan="2" data-stat="header_penalties">Penalties</th>, <th aria-label="" class=" over_header center" colspan="3" data-stat="header_turnovers">Turnovers</th>, <tr>
# <th aria-label="Rank" class="ranker poptip sort_default_asc right" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>
# <th aria-label="Date" class=" poptip sort_default_asc left" data-stat="date_game" scope="col">Date</th>
# <th aria-label="game_location" class=" poptip left" data-stat="game_location" scope="col"></th>
# <th aria-label="Opponent" class=" poptip sort_default_asc left" data-stat="opp_name" scope="col">Opponent</th>
# <th aria-label="Result" class=" poptip left" data-stat="game_result" scope="col">Result</th>
# <th aria-label="Pass Completions" class=" poptip right" data-over-header="Passing" data-stat="pass_cmp" data-tip="Pass Completions" scope="col">Cmp</th>
# <th aria-label="Pass Attempts" class=" poptip right" data-over-header="Passing" data-stat="pass_att" data-tip="Pass Attempts" scope="col">Att</th>
# <th aria-label="Pass Completion Percentage" class=" poptip right" data-filter="1" data-name="Pass Completion Percentage" data-over-header="Passing" data-stat="pass_cmp_pct" data-tip="Pass Completion Percentage" scope="col">Pct</th>
# <th aria-label="Passing Yards" class=" poptip right" data-over-header="Passing" data-stat="pass_yds" data-tip="Passing Yards" scope="col">Yds</th>
# <th aria-label="Passing Touchdowns" class=" poptip right" data-over-header="Passing" data-stat="pass_td" data-tip="Passing Touchdowns" scope="col">TD</th>
# <th aria-label="Rush Attempts" class=" poptip right" data-over-header="Rushing" data-stat="rush_att" data-tip="Rush Attempts" scope="col">Att</th>
# <th aria-label="Rushing Yards" class=" poptip right" data-over-header="Rushing" data-stat="rush_yds" data-tip="Rushing Yards" scope="col">Yds</th>
# <th aria-label="Rushing Yards Per Attempt" class=" poptip right" data-filter="1" data-name="Rushing Yards Per Attempt" data-over-header="Rushing" data-stat="rush_yds_per_att" data-tip="Rushing Yards Per Attempt" scope="col">Avg</th>
# <th aria-label="Rushing Touchdowns" class=" poptip right" data-over-header="Rushing" data-stat="rush_td" data-tip="Rushing Touchdowns" scope="col">TD</th>
# <th aria-label="Total Plays" class=" poptip right" data-over-header="Total Offense" data-stat="tot_plays" data-tip="Total Plays (Pass and Rush Attempts)" scope="col">Plays</th>
# <th aria-label="Total Yards" class=" poptip right" data-over-header="Total Offense" data-stat="tot_yds" data-tip="Total Yards (Passing and Rushing Yards)" scope="col">Yds</th>
# <th aria-label="Total Yards Per Play" class=" poptip right" data-filter="1" data-name="Total Yards Per Play" data-over-header="Total Offense" data-stat="tot_yds_per_play" data-tip="Total Yards Per Play" scope="col">Avg</th>
# <th aria-label="First Downs by Pass" class=" poptip right" data-over-header="First Downs" data-stat="first_down_pass" data-tip="First Downs by Pass" scope="col">Pass</th>
# <th aria-label="First Downs by Rush" class=" poptip right" data-over-header="First Downs" data-stat="first_down_rush" data-tip="First Downs by Rush" scope="col">Rush</th>
# <th aria-label="First Downs by Penalty" class=" poptip right" data-over-header="First Downs" data-stat="first_down_penalty" data-tip="First Downs by Penalty" scope="col">Pen</th>
# <th aria-label="First Downs" class=" poptip right" data-over-header="First Downs" data-stat="first_down" data-tip="First Downs" scope="col">Tot</th>
# <th aria-label="Penalties" class=" poptip right" data-over-header="Penalties" data-stat="penalty" data-tip="Penalties" scope="col">No.</th>
# <th aria-label="Penalty Yards" class=" poptip right" data-over-header="Penalties" data-stat="penalty_yds" data-tip="Penalty Yards" scope="col">Yds</th>
# <th aria-label="Fumbles Lost" class=" poptip right" data-over-header="Turnovers" data-stat="fumbles_lost" data-tip="Fumbles Lost" scope="col">Fum</th>
# <th aria-label="Passing Interceptions" class=" poptip right" data-over-header="Turnovers" data-stat="pass_int" data-tip="Passing Interceptions" scope="col">Int</th>
# <th aria-label="Turnovers" class=" poptip right" data-over-header="Turnovers" data-stat="turnovers" data-tip="Turnovers" scope="col">Tot</th>
# </tr>, <th aria-label="Rank" class="ranker poptip sort_default_asc right" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>, <th aria-label="Date" class=" poptip sort_default_asc left" data-stat="date_game" scope="col">Date</th>, <th aria-label="game_location" class=" poptip left" data-stat="game_location" scope="col"></th>, <th aria-label="Opponent" class=" poptip sort_default_asc left" data-stat="opp_name" scope="col">Opponent</th>, <th aria-label="Result" class=" poptip left" data-stat="game_result" scope="col">Result</th>, <th aria-label="Pass Completions" class=" poptip right" data-over-header="Passing" data-stat="pass_cmp" data-tip="Pass Completions" scope="col">Cmp</th>, <th aria-label="Pass Attempts" class=" poptip right" data-over-header="Passing" data-stat="pass_att" data-tip="Pass Attempts" scope="col">Att</th>, <th aria-label="Pass Completion Percentage" class=" poptip right" data-filter="1" data-name="Pass Completion Percentage" data-over-header="Passing" data-stat="pass_cmp_pct" data-tip="Pass Completion Percentage" scope="col">Pct</th>, <th aria-label="Passing Yards" class=" poptip right" data-over-header="Passing" data-stat="pass_yds" data-tip="Passing Yards" scope="col">Yds</th>, <th aria-label="Passing Touchdowns" class=" poptip right" data-over-header="Passing" data-stat="pass_td" data-tip="Passing Touchdowns" scope="col">TD</th>, <th aria-label="Rush Attempts" class=" poptip right" data-over-header="Rushing" data-stat="rush_att" data-tip="Rush Attempts" scope="col">Att</th>, <th aria-label="Rushing Yards" class=" poptip right" data-over-header="Rushing" data-stat="rush_yds" data-tip="Rushing Yards" scope="col">Yds</th>, <th aria-label="Rushing Yards Per Attempt" class=" poptip right" data-filter="1" data-name="Rushing Yards Per Attempt" data-over-header="Rushing" data-stat="rush_yds_per_att" data-tip="Rushing Yards Per Attempt" scope="col">Avg</th>, <th aria-label="Rushing Touchdowns" class=" poptip right" data-over-header="Rushing" data-stat="rush_td" data-tip="Rushing Touchdowns" scope="col">TD</th>, <th aria-label="Total Plays" class=" poptip right" data-over-header="Total Offense" data-stat="tot_plays" data-tip="Total Plays (Pass and Rush Attempts)" scope="col">Plays</th>, <th aria-label="Total Yards" class=" poptip right" data-over-header="Total Offense" data-stat="tot_yds" data-tip="Total Yards (Passing and Rushing Yards)" scope="col">Yds</th>, <th aria-label="Total Yards Per Play" class=" poptip right" data-filter="1" data-name="Total Yards Per Play" data-over-header="Total Offense" data-stat="tot_yds_per_play" data-tip="Total Yards Per Play" scope="col">Avg</th>, <th aria-label="First Downs by Pass" class=" poptip right" data-over-header="First Downs" data-stat="first_down_pass" data-tip="First Downs by Pass" scope="col">Pass</th>, <th aria-label="First Downs by Rush" class=" poptip right" data-over-header="First Downs" data-stat="first_down_rush" data-tip="First Downs by Rush" scope="col">Rush</th>, <th aria-label="First Downs by Penalty" class=" poptip right" data-over-header="First Downs" data-stat="first_down_penalty" data-tip="First Downs by Penalty" scope="col">Pen</th>, <th aria-label="First Downs" class=" poptip right" data-over-header="First Downs" data-stat="first_down" data-tip="First Downs" scope="col">Tot</th>, <th aria-label="Penalties" class=" poptip right" data-over-header="Penalties" data-stat="penalty" data-tip="Penalties" scope="col">No.</th>, <th aria-label="Penalty Yards" class=" poptip right" data-over-header="Penalties" data-stat="penalty_yds" data-tip="Penalty Yards" scope="col">Yds</th>, <th aria-label="Fumbles Lost" class=" poptip right" data-over-header="Turnovers" data-stat="fumbles_lost" data-tip="Fumbles Lost" scope="col">Fum</th>, <th aria-label="Passing Interceptions" class=" poptip right" data-over-header="Turnovers" data-stat="pass_int" data-tip="Passing Interceptions" scope="col">Int</th>, <th aria-label="Turnovers" class=" poptip right" data-over-header="Turn ...

# %%
comments=soup.find_all(string=lambda text:isinstance(text,Comment))
for comment in comments:
    comment=BeautifulSoup(str(comment), 'lxml')
    defensive_log = comment.find(table) #search as ordinary tag

print(defensive_log)
# Out:
# None

# %%
defensive_log['class'][1]
# Out:
# 'stats_table'
